# %% [markdown]
# # Forestfires

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pyp

# %%
df=pd.read_csv(r"forestfires.csv")

# %%
df
# Out:
#      X  Y month  FFMC    DMC     DC   ISI  temp  RH
# 0    7  5   mar  86.2   26.2   94.3   5.1   8.2  51
# 1    7  4   oct  90.6   35.4  669.1   6.7  18.0  33
# 2    7  4   oct  90.6   43.7  686.9   6.7  14.6  33
# 3    8  6   mar  91.7   33.3   77.5   9.0   8.3  97
# 4    8  6   mar  89.3   51.3  102.2   9.6  11.4  99
# ..  .. ..   ...   ...    ...    ...   ...   ...  ..
# 512  4  3   aug  81.6   56.7  665.6   1.9  27.8  32
# 513  2  4   aug  81.6   56.7  665.6   1.9  21.9  71
# 514  7  4   aug  81.6   56.7  665.6   1.9  21.2  70
# 515  1  4   aug  94.4  146.0  614.7  11.3  25.6  42
# 516  6  3   nov  79.5    3.0  106.7   1.1  11.8  31
#
# [517 rows x 9 columns]

# %%
df.head()
# Out:
#    X  Y month  FFMC   DMC     DC  ISI  temp  RH
# 0  7  5   mar  86.2  26.2   94.3  5.1   8.2  51
# 1  7  4   oct  90.6  35.4  669.1  6.7  18.0  33
# 2  7  4   oct  90.6  43.7  686.9  6.7  14.6  33
# 3  8  6   mar  91.7  33.3   77.5  9.0   8.3  97
# 4  8  6   mar  89.3  51.3  102.2  9.6  11.4  99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   FFMC    517 non-null    float64
#  4   DMC     517 non-null    float64
#  5   DC      517 non-null    float64
#  6   ISI     517 non-null    float64
#  7   temp    517 non-null    float64
#  8   RH      517 non-null    int64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 36.5+ KB

# %%
df.isnull().sum()
# Out:
# X        0
# Y        0
# month    0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# dtype: int64

# %%
df.describe()
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH
# count  517.000000  517.000000
# mean    18.889168   44.288201
# std      5.806625   16.317469
# min      2.200000   15.000000
# 25%     15.500000   33.000000
# 50%     19.300000   42.000000
# 75%     22.800000   53.000000
# max     33.300000  100.000000

# %% [markdown]
# # Data Visualization

# %%
pyp.scatter(df.month,df.temp)

# %%
import seaborn as sns

# %%
sns.relplot(data=df,x='month',y='temp',hue='month')

# %%
corr=df.corr()

# %%
sns.heatmap(corr,linewidth=1,cmap="viridis",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Finding the count of Objects

# %%
df.X.value_counts()
# Out:
# 4    91
# 6    86
# 2    73
# 8    61
# 7    60
# 3    55
# 1    48
# 5    30
# 9    13
# Name: X, dtype: int64

# %%
df.Y.value_counts()
# Out:
# 4    203
# 5    125
# 6     74
# 3     64
# 2     44
# 9      6
# 8      1
# Name: Y, dtype: int64

# %%
df.month.value_counts()
# Out:
# aug    184
# sep    172
# mar     54
# jul     32
# feb     20
# jun     17
# oct     15
# apr      9
# dec      9
# jan      2
# may      2
# nov      1
# Name: month, dtype: int64

# %%
df.FFMC.value_counts()
# Out:
# 92.1    28
# 91.6    28
# 91.0    22
# 91.7    19
# 92.4    16
#         ..
# 86.9     1
# 85.2     1
# 53.4     1
# 85.1     1
# 94.4     1
# Name: FFMC, Length: 106, dtype: int64

# %%
df.temp.value_counts()
# Out:
# 17.4    8
# 19.6    8
# 15.4    7
# 20.6    7
# 20.4    6
#        ..
# 16.3    1
# 12.8    1
# 10.4    1
# 8.7     1
# 25.6    1
# Name: temp, Length: 192, dtype: int64

# %%
df.RH.value_counts()
# Out:
# 27    33
# 39    24
# 35    20
# 43    17
# 42    17
#       ..
# 96     1
# 97     1
# 99     1
# 18     1
# 69     1
# Name: RH, Length: 75, dtype: int64

# %% [markdown]
# # Deleting the unwanted data

# %%
df=df.drop(["DC"],axis=1)

# %% [markdown]
# # Data After Cleaning

# %%
df.head()
# Out:
#    X  Y month  FFMC   DMC  ISI  temp  RH
# 0  7  5   mar  86.2  26.2  5.1   8.2  51
# 1  7  4   oct  90.6  35.4  6.7  18.0  33
# 2  7  4   oct  90.6  43.7  6.7  14.6  33
# 3  8  6   mar  91.7  33.3  9.0   8.3  97
# 4  8  6   mar  89.3  51.3  9.6  11.4  99

# %%
df.tail()
# Out:
#      X  Y month  FFMC    DMC   ISI  temp  RH
# 512  4  3   aug  81.6   56.7   1.9  27.8  32
# 513  2  4   aug  81.6   56.7   1.9  21.9  71
# 514  7  4   aug  81.6   56.7   1.9  21.2  70
# 515  1  4   aug  94.4  146.0  11.3  25.6  42
# 516  6  3   nov  79.5    3.0   1.1  11.8  31

# %% [markdown]
# # Lable Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
print(df.month.value_counts())
# Out:
# aug    184
# sep    172
# mar     54
# jul     32
# feb     20
# jun     17
# oct     15
# apr      9
# dec      9
# jan      2
# may      2
# nov      1
# Name: month, dtype: int64

# %%
df.month=le.fit_transform(df.month)
print(df.month.value_counts())
# Out:
# 1     184
# 11    172
# 7      54
# 5      32
# 3      20
# 6      17
# 10     15
# 0       9
# 2       9
# 4       2
# 8       2
# 9       1
# Name: month, dtype: int64

# %%
df.head()
# Out:
#    X  Y  month  FFMC   DMC  ISI  temp  RH
# 0  7  5      7  86.2  26.2  5.1   8.2  51
# 1  7  4     10  90.6  35.4  6.7  18.0  33
# 2  7  4     10  90.6  43.7  6.7  14.6  33
# 3  8  6      7  91.7  33.3  9.0   8.3  97
# 4  8  6      7  89.3  51.3  9.6  11.4  99

# %% [markdown]
# # Preprocessing the Data

# %%
#df.Address=le.fit_transform(df.Address)
df.X=le.fit_transform(df.X)
df.Y=le.fit_transform(df.Y)
df.month=le.fit_transform(df.month)
df.temp=le.fit_transform(df.temp)
df.RH=le.fit_transform(df.RH)

# %%
df.shape
# Out:
# (517, 8)

# %%
df.head()
# Out:
#    X  Y  month  FFMC   DMC  ISI  temp  RH
# 0  3  3      7  86.2  26.2  5.1    12  34
# 1  2  2     10  90.6  35.4  6.7    85  16
# 2  2  2     10  90.6  43.7  6.7    55  16
# 3  4  4      7  91.7  33.3  9.0    13  72
# 4  4  4      7  89.3  51.3  9.6    30  73

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Spliting into independent & dependent variables

# %%
#independent variable
x=df.iloc[:,:7]
x.head()
# Out:
#    X  Y  month  FFMC   DMC  ISI  temp
# 0  3  3      7  86.2  26.2  5.1    12
# 1  2  2     10  90.6  35.4  6.7    85
# 2  2  2     10  90.6  43.7  6.7    55
# 3  4  4      7  91.7  33.3  9.0    13
# 4  4  4      7  89.3  51.3  9.6    30

# %%
#dependent variable
y=df.iloc[:,7:]
y.head()
# Out:
#    RH
# 0  34
# 1  16
# 2  16
# 3  72
# 4  73

# %%
ss=StandardScaler()
x=ss.fit_transform(x)
y=ss.fit_transform(y)

# %%
x.shape
# Out:
# (517, 7)

# %%
y.shape
# Out:
# (517, 1)

# %%
x
# Out:
# array([[ 0.60328436,  0.60328436,  0.28422225, ..., -1.32332557,
#         -0.86094557, -1.78165157],
#        [-0.24196771, -0.24196771,  0.97087134, ..., -1.17954077,
#         -0.50968827, -0.22894959],
#        [-0.24196771, -0.24196771,  0.97087134, ..., -1.04982188,
#         -0.50968827, -0.86704629],
#        ...,
#        [-0.24196771, -0.24196771, -1.08907592, ..., -0.84664771,
#         -1.56346017,  0.430417  ],
#        [-0.24196771, -0.24196771, -1.08907592, ...,  0.54900254,
#          0.50017647,  1.28121261],
#        [-1.08721978, -1.08721978,  0.74198831, ..., -1.68591332,
#         -1.73908882, -1.31371399]])

# %%
x=pd.DataFrame(x)
x.head()
# Out:
#           0         1         2         3         4         5         6
# 0  0.603284  0.603284  0.284222 -0.805959 -1.323326 -0.860946 -1.781652
# 1 -0.241968 -0.241968  0.970871 -0.008102 -1.179541 -0.509688 -0.228950
# 2 -0.241968 -0.241968  0.970871 -0.008102 -1.049822 -0.509688 -0.867046
# 3  1.448536  1.448536  0.284222  0.191362 -1.212361 -0.004756 -1.760382
# 4  1.448536  1.448536  0.284222 -0.243833 -0.931043  0.126966 -1.398794

# %%
y
# Out:
# array([[ 0.42794268],
#        [-0.70600794],
#        [-0.70600794],
#        [ 2.82183845],
#        [ 2.8848357 ],
#        [-0.95799697],
#        [-1.08399149],
#        [ 2.44385491],
#        [ 1.18390977],
#        [-0.26502714],
#        [ 0.42794268],
#        [-0.39102166],
#        [ 1.75088508],
#        [-0.13903263],
#        [-1.39897777],
#        [-0.01303812],
#        [-1.08399149],
#        [ 0.17595365],
#        [-0.58001343],
#        [-0.01303812],
#        [-0.26502714],
#        [-0.39102166],
#        [-0.01303812],
#        [-0.07603537],
#        [-0.7690052 ],
#        [ 0.99491799],
#        [-0.64301069],
#        [ 0.23895091],
#        [-1.27298326],
#        [-0.3280244 ],
#        [-1.27298326],
#        [ 2.12886862],
#        [-0.45401892],
#        [-0.3280244 ],
#        [-0.7690052 ],
#        [ 1.12091251],
#        [-1.27298326],
#        [ 0.99491799],
#        [-1.08399149],
#        [-0.07603537],
#        [-0.45401892],
#        [-0.13903263],
#        [ 0.61693445],
#        [ 0.23895091],
#        [ 1.87687959],
#        [-1.27298326],
#        [ 1.62489056],
#        [-0.51701617],
#        [-0.58001343],
#        [ 0.1129564 ],
#        [-1.6509668 ],
#        [-0.64301069],
#        [-0.13903263],
#        [-0.13903263],
#        [ 0.04995914],
#        [-1.27298326],
#        [ 1.18390977],
#        [ 0.36494542],
#        [-0.26502714],
#        [ 0.42794268],
#        [-0.3280244 ],
#        [ 0.93192074],
#        [-0.58001343],
#        [-0.70600794],
#        [-0.83200246],
#        [-0.01303812],
#        [-0.45401892],
#        [-0.70600794],
#        [-0.70600794],
#        [-1.14698874],
#        [-1.08399149],
#        [-0.45401892],
#        [-1.209986  ],
#        [-0.07603537],
#        [-0.89499971],
#        [ 2.19186588],
#        [-0.07603537],
#        [ 1.75088508],
#        [ 1.37290154],
#        [-1.52497228],
#        [-0.3280244 ],
#        [-0.01303812],
#        [ 0.42794268],
#        [ 0.17595365],
#        [ 0.04995914],
#        [-1.71396406],
#        [-1.08399149],
#        [-0.64301069],
#        [-0.51701617],
#        [-1.209986  ],
#        [ 0.93192074],
#        [-1.27298326],
#        [-0.7690052 ],
#        [-0.07603537],
#        [-1.33598051],
#        [ 1.24690702],
#        [ 0.23895091],
#        [-1.27298326],
#        [ 2.50685216],
#        [-0.3280244 ],
#        [-0.3280244 ],
#        [ 1.37290154],
#        [-0.26502714],
#        [-0.95799697],
#        [ 2.12886862],
#        [ 0.49093994],
#        [-0.95799697],
#        [-0.70600794],
#        [ 0.04995914],
#        [ 0.74292897],
#        [-0.07603537],
#        [-1.58796954],
#        [-0.3280244 ],
#        [-0.58001343],
#        [-1.08399149],
#        [-1.08399149],
#        [-0.89499971],
#        [-1.08399149],
#        [-0.89499971],
#        [-0.51701617],
#        [ 1.87687959],
#        [-0.07603537],
#        [-0.13903263],
#        [ 0.04995914],
#        [ 0.36494542],
#        [-1.27298326],
#        [ 0.30194817],
#        [-0.07603537],
#        [ 0.1129564 ],
#        [-0.58001343],
#        [-0.26502714],
#        [-0.3280244 ],
#        [ 0.1129564 ],
#        [-0.13903263],
#        [-0.39102166],
#        [ 0.49093994],
#        [ 0.86892348],
#        [ 1.37290154],
#        [-0.13903263],
#        [-0.39102166],
#        [-0.3280244 ],
#        [-0.83200246],
#        [ 0.42794268],
#        [ 0.5539372 ],
#        [-0.7690052 ],
#        [-1.33598051],
#        [-0.26502714],
#        [-1.02099423],
#        [-0.07603537],
#        [-1.209986  ],
#        [-0.3280244 ],
#        [-0.95799697],
#        [-0.07603537],
#        [ 0.17595365],
#        [-1.08399149],
#        [ 0.17595365],
#        [-1.08399149],
#        [ 0.04995914],
#        [-0.58001343],
#        [-0.64301069],
#        [-0.95799697],
#        [-0.20202989],
#        [-0.83200246],
#        [ 0.74292897],
#        [ 1.43589879],
#        [ 1.62489056],
#        [ 0.17595365],
#        [-0.70600794],
#        [-1.14698874],
#        [ 0.04995914],
#        [-0.58001343],
#        [ 0.36494542],
#        [-0.3280244 ],
#        [-0.3280244 ],
#        [ 0.5539372 ],
#        [-0.3280244 ],
#        [ 0.61693445],
#        [-0.01303812],
#        [ 0.04995914],
#        [ 1.37290154],
#        [-0.7690052 ],
#        [-0.7690052 ],
#        [ 0.5539372 ],
#        [ 0.04995914],
#        [-0.64301069],
#        [ 0.1129564 ],
#        [-0.3280244 ],
#        [-0.13903263],
#        [-0.13903263],
#        [ 0.99491799],
#        [-0.70600794],
#        [-1.02099423],
#        [-1.33598051],
#        [-1.209986  ],
#        [-1.33598051],
#        [-0.51701617],
#        [ 0.61693445],
#        [-1.71396406],
#        [ 0.93192074],
#        [-0.39102166],
#        [-0.70600794],
#        [ 0.61693445],
#        [ 1.49889605],
#        [-0.45401892],
#        [ 1.24690702],
#        [-0.64301069],
#        [-0.83200246],
#        [-0.45401892],
#        [-0.70600794],
#        [-1.14698874],
#        [-1.209986  ],
#        [ 2.75884119],
#        [ 0.17595365],
#        [ 0.1129564 ],
#        [-1.08399149],
#        [-1.08399149],
#        [ 0.99491799],
#        [ 1.81388234],
#        [-1.52497228],
#        [-1.08399149],
#        [ 0.93192074],
#        [ 0.30194817],
#        [ 0.1129564 ],
#        [ 2.19186588],
#        [ 0.80592622],
#        [-0.3280244 ],
#        [-0.01303812],
#        [-0.64301069],
#        [-1.14698874],
#        [-0.07603537],
#        [-1.39897777],
#        [-1.08399149],
#        [-0.07603537],
#        [-0.51701617],
#        [-1.209986  ],
#        [-0.20202989],
#        [ 0.1129564 ],
#        [-0.26502714],
#        [-1.08399149],
#        [ 1.93987685],
#        [ 0.42794268],
#        [-1.46197503],
#        [ 1.37290154],
#        [ 1.81388234],
#        [ 0.61693445],
#        [-0.39102166],
#        [-0.3280244 ],
#        [ 1.62489056],
#        [-1.02099423],
#        [-0.26502714],
#        [-1.209986  ],
#        [-0.51701617],
#        [-0.45401892],
#        [-0.39102166],
#        [-0.20202989],
#        [ 0.1129564 ],
#        [-0.20202989],
#        [-0.01303812],
#        [ 0.93192074],
#        [-0.26502714],
#        [-0.7690052 ],
#        [ 2.38085765],
#        [-0.13903263],
#        [-0.3280244 ],
#        [ 0.5539372 ],
#        [ 0.61693445],
#        [ 0.67993171],
#        [-1.27298326],
#        [-0.7690052 ],
#        [ 0.5539372 ],
#        [ 0.74292897],
#        [ 0.86892348],
#        [ 0.17595365],
#        [ 0.80592622],
#        [ 1.05791525],
#        [ 1.05791525],
#        [-1.39897777],
#        [-1.39897777],
#        [-1.39897777],
#        [-1.39897777],
#        [ 0.93192074],
#        [-1.27298326],
#        [ 0.42794268],
#        [-0.58001343],
#        [ 0.1129564 ],
#        [-0.26502714],
#        [ 2.63284668],
#        [ 0.30194817],
#        [-0.7690052 ],
#        [-0.89499971],
#        [ 0.5539372 ],
#        [-0.3280244 ],
#        [-0.26502714],
#        [-1.02099423],
#        [ 1.43589879],
#        [ 0.23895091],
#        [ 0.1129564 ],
#        [ 0.04995914],
#        [-0.07603537],
#        [ 2.63284668],
#        [-1.209986  ],
#        [-0.3280244 ],
#        [-0.39102166],
#        [-0.39102166],
#        [ 2.69584393],
#        [ 0.49093994],
#        [ 0.5539372 ],
#        [-0.58001343],
#        [ 0.04995914],
#        [-1.08399149],
#        [-1.08399149],
#        [-1.02099423],
#        [ 2.12886862],
#        [-1.08399149],
#        [-0.20202989],
#        [-0.89499971],
#        [-1.27298326],
#        [-1.27298326],
#        [-1.08399149],
#        [-1.02099423],
#        [-0.64301069],
#        [-1.02099423],
#        [-1.02099423],
#        [-0.3280244 ],
#        [ 0.74292897],
#        [-1.08399149],
#        [-1.08399149],
#        [-0.7690052 ],
#        [-0.58001343],
#        [-1.08399149],
#        [-1.08399149],
#        [-1.02099423],
#        [-0.20202989],
#        [ 0.61693445],
#        [ 0.42794268],
#        [ 2.44385491],
#        [-0.01303812],
#        [-0.64301069],
#        [-0.58001343],
#        [-0.20202989],
#        [-0.01303812],
#        [ 0.42794268],
#        [-0.45401892],
#        [ 0.42794268],
#        [ 1.37290154],
#        [-0.07603537],
#        [-0.58001343],
#        [ 1.93987685],
#        [ 0.80592622],
#        [ 1.24690702],
#        [ 1.93987685],
#        [ 0.5539372 ],
#        [-0.07603537],
#        [ 0.17595365],
#        [ 0.36494542],
#        [-0.58001343],
#        [-0.58001343],
#        [ 0.67993171],
#        [-0.3280244 ],
#        [-0.3280244 ],
#        [-0.13903263],
#        [ 0.04995914],
#        [ 1.24690702],
#        [ 0.5539372 ],
#        [-0.58001343],
#        [ 0.04995914],
#        [-0.39102166],
#        [-1.08399149],
#        [ 0.17595365],
#        [ 2.06587136],
#        [ 2.06587136],
#        [ 0.86892348],
#        [ 1.93987685],
#        [-0.13903263],
#        [ 2.12886862],
#        [ 0.80592622],
#        [ 0.61693445],
#        [-0.13903263],
#        [ 0.42794268],
#        [ 2.94783296],
#        [-0.3280244 ],
#        [ 1.18390977],
#        [-0.95799697],
#        [ 0.86892348],
#        [-0.01303812],
#        [ 0.36494542],
#        [ 0.67993171],
#        [ 0.23895091],
#        [-0.64301069],
#        [-0.64301069],
#        [ 1.68788782],
#        [ 0.1129564 ],
#        [-0.07603537],
#        [-1.52497228],
#        [ 1.49889605],
#        [ 1.12091251],
#        [ 0.67993171],
#        [-0.70600794],
#        [-0.7690052 ],
#        [-0.64301069],
#        [-0.64301069],
#        [ 0.1129564 ],
#        [-0.51701617],
#        [-0.20202989],
#        [-0.64301069],
#        [-1.08399149],
#        [ 1.43589879],
#        [ 0.1129564 ],
#        [-0.01303812],
#        [-0.83200246],
#        [-0.13903263],
#        [ 0.5539372 ],
#        [-1.08399149],
#        [-0.70600794],
#        [ 0.36494542],
#        [-1.08399149],
#        [-0.3280244 ],
#        [-1.27298326],
#        [-0.13903263],
#        [-0.51701617],
#        [-0.51701617],
#        [-1.52497228],
#        [-1.08399149],
#        [ 0.23895091],
#        [-0.83200246],
#        [ 0.74292897],
#        [ 0.74292897],
#        [-0.70600794],
#        [-0.64301069],
#        [-0.01303812],
#        [ 0.04995914],
#        [-0.26502714],
#        [-0.39102166],
#        [ 1.37290154],
#        [ 0.04995914],
#        [ 0.42794268],
#        [-0.58001343],
#        [ 1.81388234],
#        [ 0.5539372 ],
#        [ 0.1129564 ],
#        [ 0.86892348],
#        [-0.95799697],
#        [ 1.24690702],
#        [ 2.12886862],
#        [ 0.86892348],
#        [ 2.25486313],
#        [ 1.62489056],
#        [-0.58001343],
#        [ 2.06587136],
#        [ 1.05791525],
#        [ 0.30194817],
#        [ 2.56984942],
#        [ 1.30990428],
#        [ 0.61693445],
#        [ 0.74292897],
#        [ 0.23895091],
#        [ 0.93192074],
#        [ 0.36494542],
#        [ 1.24690702],
#        [ 1.75088508],
#        [ 1.24690702],
#        [ 1.24690702],
#        [ 2.00287411],
#        [ 2.31786039],
#        [ 2.06587136],
#        [ 0.93192074],
#        [ 0.04995914],
#        [-0.20202989],
#        [-1.08399149],
#        [-0.70600794],
#        [-1.08399149],
#        [-0.26502714],
#        [ 2.19186588],
#        [ 0.36494542],
#        [-0.58001343],
#        [-0.26502714],
#        [-1.02099423],
#        [ 0.04995914],
#        [ 2.31786039],
#        [ 0.80592622],
#        [-1.209986  ],
#        [-1.33598051],
#        [-0.26502714],
#        [-1.08399149],
#        [-1.209986  ],
#        [-1.02099423],
#        [-0.07603537],
#        [-0.64301069],
#        [ 1.68788782],
#        [ 0.86892348],
#        [-0.70600794],
#        [-1.39897777],
#        [-1.08399149],
#        [-0.95799697],
#        [-0.89499971],
#        [-0.13903263],
#        [-1.14698874],
#        [-1.08399149],
#        [-1.14698874],
#        [ 1.18390977],
#        [ 1.30990428],
#        [ 1.30990428],
#        [ 1.56189331],
#        [-0.89499971],
#        [-0.95799697],
#        [-0.58001343],
#        [ 1.81388234],
#        [-0.20202989],
#        [-0.20202989],
#        [ 1.68788782],
#        [ 1.12091251],
#        [-0.58001343],
#        [-0.7690052 ],
#        [ 1.68788782],
#        [ 1.62489056],
#        [-0.13903263],
#        [-0.83200246]])

# %%
y=pd.DataFrame(y)
y.head()
# Out:
#           0
# 0  0.427943
# 1 -0.706008
# 2 -0.706008
# 3  2.821838
# 4  2.884836

# %% [markdown]
# # Train,Test&Split the Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (413, 7)
# (104, 7)
# (413, 1)
# (104, 1)

# %%
x_train
# Out:
#             0         1         2         3         4         5         6
# 386 -0.241968 -0.241968  1.199754 -0.026235 -0.221496  0.522130  0.302798
# 56  -1.087220 -1.087220  1.199754 -0.062501 -0.471557 -0.597503 -0.271489
# 457 -0.241968 -0.241968 -1.089076  0.191362  1.258549 -0.268199  0.175178
# 60  -1.932472 -1.932472  0.284222 -0.243833 -0.931043  0.126966 -1.377524
# 229  1.448536  1.448536 -1.089076  0.282028 -0.454365  0.631898 -0.526728
# ..        ...       ...       ...       ...       ...       ...       ...
# 70   0.603284  0.603284  0.284222  0.100697 -0.977929  0.763619 -0.654347
# 277 -0.241968 -0.241968 -0.860193 -0.951024 -1.335829 -1.409785 -1.994350
# 9    0.603284  0.603284  1.199754  0.336427 -0.357467 -0.421874  0.749465
# 359 -0.241968 -0.241968  1.199754  0.336427  0.173912  0.258687  0.409147
# 192 -1.932472 -1.932472 -1.089076  0.753489 -0.040203  1.751531  1.111053
#
# [413 rows x 7 columns]

# %% [markdown]
# # Creating the model MUltiLinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr=LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict=mlr.predict(x_test)

# %%
predict
# Out:
# array([[ 0.61765701],
#        [-0.92304457],
#        [ 0.43657453],
#        [-1.03781512],
#        [ 0.34483285],
#        [-0.46436787],
#        [ 0.02562926],
#        [ 0.0110395 ],
#        [ 1.04832608],
#        [ 0.31812432],
#        [-0.01956516],
#        [ 0.95402199],
#        [-1.15535874],
#        [ 0.48491417],
#        [ 2.28269683],
#        [ 0.68549801],
#        [ 0.1831137 ],
#        [-0.89574224],
#        [ 0.55344143],
#        [-1.08117826],
#        [ 0.42735558],
#        [-0.89603539],
#        [ 0.67042006],
#        [ 0.26743051],
#        [ 0.61053834],
#        [-0.51205119],
#        [-1.25696869],
#        [ 0.06712775],
#        [-0.90781481],
#        [-0.39612903],
#        [ 0.57799106],
#        [-0.27892704],
#        [ 0.3408231 ],
#        [-1.01941318],
#        [-0.38996125],
#        [ 0.22449933],
#        [-0.05228129],
#        [ 0.36080509],
#        [-0.95573807],
#        [-1.22991288],
#        [-0.47298728],
#        [-0.14942392],
#        [-0.03255731],
#        [-0.54105769],
#        [-1.02437253],
#        [-0.07739539],
#        [-0.15550593],
#        [-0.36611556],
#        [ 0.08716434],
#        [-0.46514278],
#        [ 1.06330142],
#        [ 0.2333711 ],
#        [ 0.67701862],
#        [-0.1539132 ],
#        [ 0.86496574],
#        [-0.51172215],
#        [ 0.87307717],
#        [ 1.07637689],
#        [ 0.27018726],
#        [ 0.3817488 ],
#        [ 0.5842313 ],
#        [-0.82382412],
#        [-1.66572038],
#        [-0.5138287 ],
#        [ 0.18580369],
#        [-0.01711785],
#        [-0.36585378],
#        [-0.28166124],
#        [-0.04137786],
#        [ 0.17611359],
#        [-0.81925862],
#        [ 0.22118653],
#        [-0.18089603],
#        [-0.2259388 ],
#        [-0.45255242],
#        [ 0.50670478],
#        [ 1.56510772],
#        [ 0.04634293],
#        [-0.19502154],
#        [ 0.88546343],
#        [-0.23566135],
#        [-0.36353865],
#        [ 0.00275793],
#        [ 0.98712366],
#        [ 0.17927077],
#        [-0.36794013],
#        [ 0.01157924],
#        [-1.00108254],
#        [-0.16041358],
#        [ 0.47294392],
#        [-0.99835049],
#        [-0.96798766],
#        [ 0.16116252],
#        [-0.21529441],
#        [ 0.44587451],
#        [ 0.07940028],
#        [ 0.12325256],
#        [ 0.20868282],
#        [ 0.33542758],
#        [-1.27581727],
#        [ 0.62992954],
#        [ 0.1699408 ],
#        [-0.48615677],
#        [-0.65258226]])

# %%
y_test.head()
# Out:
#             0
# 213  0.112956
# 435  0.427943
# 343  0.427943
# 230 -1.398978
# 171  0.364945

# %%
from sklearn.metrics import r2_score
r2_score(mlr.predict(x_test),y_test)
# Out:
# -0.3826824927639907

# %%
x_test.head()
# Out:
#             0         1         2         3         4         5         6
# 213 -1.087220 -1.087220  0.284222 -0.552096 -0.916977 -0.882899 -1.462603
# 435  0.603284  0.603284 -0.173544  0.028164 -0.409042 -0.751178  0.962164
# 343  1.448536  1.448536  1.199754  0.155096  0.300505 -0.334060 -0.633078
# 230 -0.241968 -0.241968  1.199754  0.408960  0.350517  0.039151  1.408832
# 171  1.448536  1.448536 -1.089076 -0.914758 -0.319958 -0.531642 -0.335299

# %%
r2_score(mlr.predict(x_train),y_train)
# Out:
# -0.009108517879719003

# %% [markdown]
# # PolynomialLinearRegression Model

# %%
from sklearn.preprocessing import PolynomialFeatures
pr=PolynomialFeatures(degree=6)
px=pr.fit_transform(x)

# %%
px[:5]
# Out:
# array([[ 1.00000000e+00,  6.03284357e-01,  6.03284357e-01, ...,
#          7.46865652e+00,  1.54557316e+01,  3.19842850e+01],
#        [ 1.00000000e+00, -2.41967709e-01, -2.41967709e-01, ...,
#          7.13787210e-04,  3.20629883e-04,  1.44025446e-04],
#        [ 1.00000000e+00, -2.41967709e-01, -2.41967709e-01, ...,
#          1.46817701e-01,  2.49756080e-01,  4.24867702e-01],
#        [ 1.00000000e+00,  1.44853642e+00,  1.44853642e+00, ...,
#          2.17216628e-04,  8.04020374e-02,  2.97605559e+01],
#        [ 1.00000000e+00,  1.44853642e+00,  1.44853642e+00, ...,
#          6.17144013e-02, -6.79914213e-01,  7.49068820e+00]])

# %%
lr1=LinearRegression()
lr1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict=lr1.fit(x_train,y_train)

# %%
r2_score(lr1.predict(x_test),y_test)
# Out:
# -0.3826824927639907
